# %%
#EDA Tecnica exploratoria de dados.
#Para conhecimento dos dados sendo analisado.
#Identificando isso é como um pre-processamento dos dados.
import pandas as pd
import numpy as np
#df_melb= pd.read_csv("melb_data.csv")
#df_melb.head(5)

# %%
df_melb.shape
# Out:
# (13580, 21)

# %%
df_melb.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
df_melb.columns.to_list()
# Out:
# ['Suburb',
#  'Address',
#  'Rooms',
#  'Type',
#  'Price',
#  'Method',
#  'SellerG',
#  'Date',
#  'Distance',
#  'Postcode',
#  'Bedroom2',
#  'Bathroom',
#  'Car',
#  'Landsize',
#  'BuildingArea',
#  'YearBuilt',
#  'CouncilArea',
#  'Lattitude',
#  'Longtitude',
#  'Regionname',
#  'Propertycount']

# %%
df_melb.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
df_melb.Rooms.max()
# Out:
# 10

# %%
df_melb['Rooms'].min()
# Out:
# 1

# %%
pd.DataFrame(df_melb.SellerG.value_counts())
# Out:
#                SellerG
# Nelson            1565
# Jellis            1316
# hockingstuart     1167
# Barry             1011
# Ray                701
# ...                ...
# Prowse               1
# Luxe                 1
# Zahn                 1
# Homes                1
# Point                1
#
# [268 rows x 1 columns]

# %%
#DadosUnivariado   #DadosMultivariado
valores=[5,6,8,1,3,5,2,99]

# %%
#Media
#Problemas da media sao os extremos baixo e altos(OUTLAYERS)
df_melb.Rooms.mean()
# Out:
# 2.9379970544919

# %%
#Assim consegue ver os outlayers
df_melb.Rooms.value_counts()
# Out:
# 3     5881
# 2     3648
# 4     2688
# 1      681
# 5      596
# 6       67
# 7       10
# 8        8
# 10       1
# Name: Rooms, dtype: int64

# %%
#Mediana
#Problema muitos dados reptidos podem ter o deslocamento, um retoro
df_melb.Rooms.median()
# Out:
# 3.0

# %%
#Moda usada mais discreta nao em continua
#Bimodal e MultiModal
df_melb.Rooms.mode()
# Out:
# P78:  0    3
# dtype: int64

# %%
#Medidas Separatrizes: Aqui os dados sao ordenados antes
#Percentis: percentual de cada dado
print("P78:",df_melb.Rooms.quantile(q=0.78))
# Out:
# P78: 4.0

# %%
#Quartis 25% 50% 75%
print("Q1:",df_melb.Rooms.quantile(q=0.25))
print("Q2:",df_melb.Rooms.quantile(q=0.50))
print("Q3:",df_melb.Rooms.quantile(q=0.75))
# Out:
# Q1: 2.0
# Q2: 3.0
# Q3: 3.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x=df_melb.Rooms) #Azul aqui é o inter quartil
#Nao é so usar isso que as vezes os valores q saem do padrao aqui nao sao OUTLAYERS
plt.show()

# %%
#Medidas dispersão:
#intervalo   #Problemas sao dados mt alto e mt baixos
df_melb.Rooms.max()-df_melb.Rooms.min()
# Out:
# 9

# %%
#Variancia
df_melb.Rooms.var()
# Out:
# 0.9134541217970528

# %%
#Desvio padrao um dos melhores por processar os dados distribuido
df_melb.Rooms.std()
# Out:
# 0.9557479384215551

# %%
#Intervalo Interquartil um dos melhores tbm
df_melb.Rooms.quantile(q=0.75) - df_melb.Rooms.quantile(q=0.25)
# Out:
# 1.0

# %%
#Medidas de Distribuicao
#Assimetria #Pareciada com a variancias
df_melb.Rooms.skew()
# Out:
# 0.37647803278204356

# %%
#Curtose #Mostra a frenquencia dos dados   Curva de achatamento. Deixa os dados data set mais estavel?
df_melb.Rooms.kurtosis()
# Out:
# 0.7940679894603049

# %%
#Analise de Dados Multivariados:
#Covariancia:(Dois valores por vez) Valores positivo uma relaçao linear com os atributos.  Positivo Se o Valor da variavel X aumenta Y tbm aumenta VAlor igual a 0 nao tem relacao
#Nao Mostra o grau de como isso bate
df_melb.cov()
# Out:
#                        Rooms         Price       Distance      Postcode  \
# Rooms               0.913454  3.034531e+05       1.650188  4.792784e+00
# Price          303453.062516  4.087182e+11 -609771.988361  6.253131e+06
# Distance            1.650188 -6.097720e+05      34.441932  2.296337e+02
# Postcode            4.792784  6.253131e+06     229.633686  8.222312e+03
# Bedroom2            0.871655  2.939110e+05       1.677527  5.306401e+00
# Bathroom            0.391990  2.065330e+05       0.516182  7.129289e+00
# Car                 0.376089  1.471991e+05       1.483961  4.391997e+00
# Landsize           97.939125  9.569192e+07     585.591511  8.886439e+03
# BuildingArea       65.206357  3.320959e+07     324.222619  2.756541e+03
# YearBuilt          -2.388385 -8.036668e+06      54.367235  1.104740e+02
# Lattitude           0.001208 -1.078970e+04      -0.060806 -2.918686e+00
# Longtitude          0.010008  1.352974e+04       0.146014  4.196486e+00
# ...

# %%
#Correlacao  RElacao perfeita é proximo de 1 ou -1     Correlacao de pierson
df_melb.corr()
# Out:
#                   Rooms     Price  Distance  Postcode  Bedroom2  Bathroom  \
# Rooms          1.000000  0.496634  0.294203  0.055303  0.944190  0.592934
# Price          0.496634  1.000000 -0.162522  0.107867  0.475951  0.467038
# Distance       0.294203 -0.162522  1.000000  0.431514  0.295927  0.127155
# Postcode       0.055303  0.107867  0.431514  1.000000  0.060584  0.113664
# Bedroom2       0.944190  0.475951  0.295927  0.060584  1.000000  0.584685
# Bathroom       0.592934  0.467038  0.127155  0.113664  0.584685  1.000000
# Car            0.408483  0.238979  0.262994  0.050289  0.405325  0.322246
# Landsize       0.025678  0.037507  0.025004  0.024558  0.025646  0.037130
# BuildingArea   0.124127  0.090981  0.099481  0.055475  0.122319  0.111933
# YearBuilt     -0.065413 -0.323617  0.246379  0.032863 -0.053319  0.152702
# Lattitude      0.015948 -0.212934 -0.130723 -0.406104  0.015925 -0.070594
# Longtitude     0.100771  0.203656  0.239425  0.445357  0.102238  0.118971
# ...

# %%
#Summarizaçao a ragra dos cinco itens
df_melb.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
df_cervejas=pd.read_csv("./archive (1)/beers.csv")
df_cervejeiros=pd.read_csv("./archive (1)/breweries.csv")

# %%
df_cervejas.head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %%
# Out:
#    Unnamed: 0                       name           city state
# 0           0         NorthGate Brewing     Minneapolis    MN
# 1           1  Against the Grain Brewery     Louisville    KY
# 2           2   Jack's Abby Craft Lagers     Framingham    MA
# 3           3  Mike Hess Brewing Company      San Diego    CA
# 4           4    Fort Point Beer Company  San Francisco    CA

# %%
df_cervejeiros.columns=['brewery_id', 'name', 'city','state']
#juntos=df_cervejas.merge(df_cervejeiros)

# %%
juntos=df_cervejas.merge(df_cervejeiros, on=['brewery_id'])

# %%
juntos.head()
# Out:
#    Unnamed: 0    abv  ibu    id               name_x  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces  \
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0
#
#                       name_y  city state
# 0  10 Barrel Brewing Company  Bend    OR
# 1        18th Street Brewery  Gary    IN
# 2        18th Street Brewery  Gary    IN
# 3        18th Street Brewery  Gary    IN
# 4        18th Street Brewery  Gary    IN

# %%
juntos.state.value_counts().index[0]
# Out:
# ' CO'

# %%
juntos[(juntos.state==' CO') & (juntos.city=='Denver')]
# Out:
#       Unnamed: 0    abv    ibu    id                                 name_x  \
# 280          280  0.071   83.0  1850                 American India Red Ale
# 281          281  0.071   45.0  1849                    American Red Porter
# 282          282  0.078   34.0  1848                    American Red Saison
# 283          283  0.066   44.0  1847                       Colorado Red Ale
# 378          378  0.042    9.0  1522                            Agave Wheat
# 379          379  0.045   15.0   397                       SummerBright Ale
# 380          380  0.062   68.0   193                            Lucky U IPA
# 381          381  0.054   19.0    83                          Avalanche Ale
# 710          710  0.070    NaN  1944                   Incredible Pedal IPA
# 711          711  0.050    NaN  1943                  Graham Cracker Porter
# 754          754  0.052    NaN  2477             Lil' Brainless Raspberries
# ...

# %%
juntos['style'].value_counts().index[0]
# Out:
# 'American IPA'

# %%
novo=juntos.groupby(['brewery_id'])['style'].value_counts().head(100).to_frame()

# %%
#juntos['style'].unique().value_counts()
styles_npArr=juntos['style'].unique()
styles_df=pd.DataFrame(styles_npArr,columns=['style'])

# %%
styles_df=styles_df.value_counts()
